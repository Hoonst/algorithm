# %% [markdown]
# # Longest Palindromic Substring

# %%
from collections import deque

# %%
test_input = 'babad'

# %%
'ba'
'ab'
'ba'
'ad'

# %%
def longestPalindrome(s: str) -> str:
    pointer_left_2, pointer_right_2 = 0, 1
    pointer_left_3, pointer_right_3 = 0, 2
    
    while pointer_left_2 != pointer_right_2:
        part = s[pointer_left_2:pointer_right_2+1]
        print(s)
        print(part)
        whether_palindrome = isPalindrome(part)
        if whether_palindrome and pointer_right_2 <= len(s) and pointer_left_2 > 0:
            pointer_right_2+=1
            pointer_left_2 -=1
        elif not wheter_palindrome:
            pointer_left_2 += 1
            pointer_right_2 = pointer_left_2 + 1
        
def isPalindrome(s):
    s = deque(s)
    while s and len(s) > 1:
        head, tail = s.popleft(), s.pop()
        if head != tail:
            return False
    return True

# %%
longestPalindrome('baab')
# Out:
# baab
# ba
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# baab
# aa
# baab
# baab
# ...

# %%
isPalindrome('baab')
# Out:
# True

# %%
# Out:
# baab
# ba
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/fn/9dj0lp5d1vjdz651ldy376r40000gn/T/ipykernel_2535/65981731.py in <module>
# ----> 1 longestPalindrome('baab')
#
# /var/folders/fn/9dj0lp5d1vjdz651ldy376r40000gn/T/ipykernel_2535/542955129.py in longestPalindrome(s)
#      13         else:
#      14             pointer_left_2 += 1
# ---> 15             pointer_right_2 = pointer_left + 1
#      16
#      17 def isPalindrome(s):
#
# NameError: name 'pointer_left' is not defined

# %% [markdown]
# # Trapping Rain Water

# %%
def trap(height) -> int:
    start, end = 0, 1
    while start < len(height)-1:
        if height[start]:
            end += 1
# Out:
#   File "/var/folders/fn/9dj0lp5d1vjdz651ldy376r40000gn/T/ipykernel_2535/4086711225.py", line 1
#     def trap(height) -> int:
#                             ^
# IndentationError: expected an indented block

# %%
from typing import List

# %%
def trap_twoPointer(height: List[int]) -> int:
    if not height:
        return 0

    volume = 0

    left, right = 0, len(height) - 1
    left_max, right_max = height[0], height[right]

    while left < right:
        left_max = max(left_max, height[left])
        right_max = max(right_max, height[right])

        # 더 높은 쪽을 향해 투 포인터 이동
        if left_max <= right_max:
            print('--left_max <= right_max--')
            print(f'left,right {left, right}')
            print(f'left_max, right_max {left_max, right_max}')
            print(f'volume: {volume}')
            
            volume += left_max - height[left]
            left += 1
            
        else:
            print('==left_max > right_max==')
            print(f'left,right {left, right}')
            print(f'left_max, right_max {left_max, right_max}')
            print(f'volume: {volume}')
            
            volume += right_max - height[right]
            right -= 1
            
        
    return volume

# %%
test_input = [0,1,0,2,1,0,1,3,2,1,2,1]

# %%
trap_twoPointer(test_input)
# Out:
# --left_max <= right_max--
# left,right (0, 11)
# left_max, right_max (0, 1)
# volume: 0
# --left_max <= right_max--
# left,right (1, 11)
# left_max, right_max (1, 1)
# volume: 0
# --left_max <= right_max--
# left,right (2, 11)
# left_max, right_max (1, 1)
# volume: 0
# ==left_max > right_max==
# left,right (3, 11)
# left_max, right_max (2, 1)
# volume: 1
# --left_max <= right_max--
# left,right (3, 10)
# left_max, right_max (2, 2)
# volume: 1
# --left_max <= right_max--
# left,right (4, 10)
# left_max, right_max (2, 2)
# volume: 1
# --left_max <= right_max--
# left,right (5, 10)
# left_max, right_max (2, 2)
# volume: 2
# --left_max <= right_max--
# left,right (6, 10)
# left_max, right_max (2, 2)
# volume: 4
# ==left_max > right_max==
# left,right (7, 10)
# left_max, right_max (3, 2)
# volume: 5
# ==left_max > right_max==
# left,right (7, 9)
# left_max, right_max (3, 2)
# volume: 5
# ==left_max > right_max==
# left,right (7, 8)
# left_max, right_max (3, 2)
# volume: 6
# 6

# %% [markdown]
# # ThreeSum

# %%
test_nums = [-1,0,1,2,-1,-4]

# %%
def threeSum(nums):
    if len(nums) < 3:
        return []
    nums = sorted(nums)
    answer = []
    for i in range(0, len(nums)-2):
        first_num = nums[i]
        for j in range(i+1, len(nums)-1):
            for k in range(j+1, len(nums)):
                triple_sum = nums[i] + nums[j] + nums[k]
                if triple_sum > 0:
                    break
                elif nums[i] + nums[j] + nums[k] == 0:
                    answer_candidate = [nums[i], nums[j], nums[k]]
                    if answer_candidate not in answer:
                        answer.append(answer_candidate)
    return answer

# %%
threeSum(test_nums)
# Out:
# [-4, -1, -1, 0, 1, 2]
# [[-1, -1, 2], [-1, 0, 1]]

# %%
def threeSum(nums):
    if len(nums) < 3:
        return []
    nums = sorted(nums)
    answer = []
    for i in range(0, len(nums)-2):
        first_num = nums[i]
        head_index, tail_index = i+1, len(nums)-1
        while head_index < tail_index:
            temp_answer = first_num + nums[head_index] + nums[tail_index]
            temp_answer_list = [first_num, nums[head_index], nums[tail_index]]
            if temp_answer < 0:
                head_index += 1
            elif temp_answer > 0:
                tail_index -= 1
            elif (temp_answer == 0) and (temp_answer_list not in answer):
                answer.append(temp_answer_list)
                head_index += 1
            else:
                head_index += 1
    return answer

# %%
threeSum(test_nums)
# Out:
# [-4, -1, -1, 0, 1, 2]
# []
# [-4, -1, -1, 0, 1, 2]
# [[-1, -1, 2], [-1, 0, 1]]
# [-4, -1, -1, 0, 1, 2]
# [[-1, -1, 2], [-1, 0, 1]]
# [-4, -1, -1, 0, 1, 2]
# [[-1, -1, 2], [-1, 0, 1]]

# %%
def threeSum(nums):
    results = []
    nums.sort()
    
    for i in range(len(nums)-2):
        # 중복 skip
        if i > 0 and nums[i] == nums[i-1]:
            continue
        left, right = i+1, len(nums)-1
        while left < right:
            sum = nums[i] + nums[left] + nums[right]
            if sum < 0:
                left += 1
            elif sum > 0:
                right -= 1
            else:
                results.append((nums[i], nums[left], nums[right]))
                
                while left < right and nums[left] == nums[left+1]:
                    left += 1
                while left < right and nums[right] == nums[right-1]:
                    right -= 1
                left += 1
                right -= 1
    return results

# %% [markdown]
# # Array Partition 1

# %%
test = [6,2,6,5,1,2]

# %%
test = [1,4,2,3]

# %%
sorted(test)[::2]
# Out:
# [1, 3]

# %%
def arrayPairSum(nums):
    nums = sorted(nums)
    
    answer = sum([min(nums[i], nums[i+1]) for i in range(0,len(nums),2)])
    return answer

# %%
arrayPairSum(test)
# Out:
# 4
